# %% [markdown]
# ###This is a modified version of Echonest Feature Extractor, but we turned as much as we could into functions in order to call on them more easily

# %%
# !pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (2.0.7)

# %%
import urllib.parse

# %%
def spotify_setup():
  # Define URI
  uri_string = "https://example.com/path?param1=value1&param2=value2"

  # Parse the URI
  parsed_uri = urllib.parse.urlparse(uri_string)

  # Access components
  scheme = parsed_uri.scheme
  netloc = parsed_uri.netloc
  path = parsed_uri.path
  query = parsed_uri.query

  print("Scheme:", scheme)
  print("Netloc:", netloc)
  print("Path:", path)
  print("Query:", query)

# %%
spotify_setup()
# Out:
# Scheme: https
# Netloc: example.com
# Path: /path
# Query: param1=value1&param2=value2

# %%
# # Define URI
# uri_string = "https://example.com/path?param1=value1&param2=value2"

# # Parse the URI
# parsed_uri = urllib.parse.urlparse(uri_string)

# # Access components
# scheme = parsed_uri.scheme
# netloc = parsed_uri.netloc
# path = parsed_uri.path
# query = parsed_uri.query

# print("Scheme:", scheme)
# print("Netloc:", netloc)
# print("Path:", path)
# print("Query:", query)
# Out:
# Scheme: https
# Netloc: example.com
# Path: /path
# Query: param1=value1&param2=value2

# %% [markdown]
# ### Actual Spotify stuff

# %%
pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.31.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.0.7)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2023.11.17)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.1 spotipy-2.23.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import re
import pandas as pd

# %%
client_id = 'e958b5cfde674a8d8e07f1bb3cba2322'
client_secret = 'd79ebf15dbc6446084f11794f2bb32ea'
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
def song_feature_extraction(url):
    # Extract track ID from the URL
    match = re.search(r'track/(\w+)', url)
    if not match:
        print("Invalid Spotify URL")
        return None

    track_id = match.group(1)

    # Check if track_id is valid
    if not track_id:
        print("Failed to extract track ID.")
        return None

    # Construct Spotify URI
    track_uri = f'spotify:track:{track_id}'

    # Retrieve track features
    track_features = sp.audio_features(track_uri)

    # Check if track features are available
    if not track_features:
        print("Track features not available.")
        return None

    # Extract relevant features
    features = track_features[0]

    # Define the desired order of columns
    column_order = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'tempo', 'valence']

    # Filter and reorder the features
    selected_features = {col: features[col] for col in column_order}

    # Convert the selected features to a DataFrame
    df = pd.DataFrame([selected_features])

    # You can return the DataFrame or process it further if needed
    return df

# %%
df = song_feature_extraction("https://open.spotify.com/track/3CRDbSIZ4r5MsZ0YwxuEkn?si=c8501be08ef4437e")

# %%
df.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  \
# 0        0.0462         0.734   0.637          0.000023    0.0602
#
#    speechiness    tempo  valence
# 0        0.141  169.977    0.648

# %%
#@title Function to extract track features and return a DataFrame
def extract_track_features(track_id):
    # Check if track_id is valid
    if not track_id:
        print("Failed to extract track ID.")
        return None

    # Construct Spotify URI
    track_uri = f'spotify:track:{track_id}'

    # Retrieve track features
    track_features = sp.audio_features(track_uri)

    # Check if track features are available
    if not track_features:
        print("Track features not available.")
        return None

    # Extract relevant features
    features = track_features[0]

    # Display track features
    # print("Track Features:")
    # print("Acousticness:", features['acousticness'])
    # print("Danceability:", features['danceability'])
    # print("Energy:", features['energy'])
    # print("Instrumentalness:", features['instrumentalness'])
    # print("Liveness:", features['liveness'])
    # print("Speechiness:", features['speechiness'])
    # print("Tempo:", features['tempo'])
    # print("Valence:", features['valence'])

    # Creating DataFrame and adding track features to it
    columns = ['Acousticness', 'Danceability', 'Energy', 'Instrumentalness', 'Liveness', 'Speechiness', 'Tempo', 'Valence']
    df = pd.DataFrame(columns=columns)

    # Append the features to the DataFrame
    feature_values = [features['acousticness'], features['danceability'], features['energy'],
                      features['instrumentalness'], features['liveness'], features['speechiness'],
                      features['tempo'], features['valence']]

    df = df.append(pd.Series(feature_values, index=columns), ignore_index=True)

    # Display the DataFrame if needed
    print("DataFrame after adding track features:")
    # print(df)

    return df

# %%
# #@title Function to process Spotify URL and extract features

# # track_id = get_track_id(spotify_url)
# # extracted_df = extract_track_features(track_id)

# def process_spotify_url(spotify_url):
#     # Extract track ID
#     track_id = get_track_id(spotify_url)

#     # Extract track features and return DataFrame
#     extracted_df = extract_track_features(track_id)

#     return extracted_df

# %%
# # Function to extract track ID from Spotify URL
# def get_track_id(track_url):
#     match = re.search(r'track/(\w+)', track_url)
#     if match:
#         return match.group(1)
#     else:
#         print("Invalid Spotify URL")
#         return None

# %%
# spotify_url = ''
# result_df = process_spotify_url(spotify_url)
# Out:
# DataFrame after adding track features:
# <ipython-input-7-edb2994953d3>:42: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.Series(feature_values, index=columns), ignore_index=True)

# %%
# result_df.head()
# Out:
#    Acousticness  Danceability  Energy  Instrumentalness  Liveness  \
# 0         0.741         0.534   0.803          0.000061     0.307
#
#    Speechiness    Tempo  Valence
# 0       0.0743  167.983    0.969

# %%
# #Only use this if you're planning on making a csv for the song you're making
# song_title = ""
# file_name = "/content/drive/Shareddrives/Machine Learning Group Project/" + song_title + ".csv"
# print(file_name)
# Out:
# /content/drive/Shareddrives/Machine Learning Group Project/back_in_black.csv

# %%
# result_df.to_csv(file_name)

# %%
#@title Old Working Code

# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials
# import re

# client_id = 'e958b5cfde674a8d8e07f1bb3cba2322'
# client_secret = 'd79ebf15dbc6446084f11794f2bb32ea'

# sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# # Function to extract track ID from Spotify URL
# def get_track_id(track_url):
#     match = re.search(r'track/(\w+)', track_url)
#     if match:
#         return match.group(1)
#     else:
#         print("Invalid Spotify URL")
#         return None

# spotify_url = 'https://open.spotify.com/track/3CRDbSIZ4r5MsZ0YwxuEkn?si=5a73e5c96bf84505'

# track_id = get_track_id(spotify_url)

# if track_id:
#     track_uri = f'spotify:track:{track_id}'
#     track_features = sp.audio_features(track_uri)

#     if track_features:
#         # Extract relevant features
#         features = track_features[0]
#         print("Track Features:")
#         print("Acousticness:", features['acousticness'])
#         print("Danceability:", features['danceability'])
#         print("Energy:", features['energy'])
#         print("Instrumentalness:", features['instrumentalness'])
#         print("Liveness:", features['liveness'])
#         print("Speechiness:", features['speechiness'])
#         print("Tempo:", features['tempo'])
#         print("Valence:", features['valence'])
#     else:
#         print("Track features not available.")
# else:
#     print("Failed to extract track ID.")

# import pandas as pd

# # Assuming you have an existing DataFrame or creating an empty one
# columns = ['Acousticness', 'Danceability', 'Energy', 'Instrumentalness', 'Liveness', 'Speechiness', 'Tempo', 'Valence']
# df = pd.DataFrame(columns=columns)

# if track_id:
#     track_uri = f'spotify:track:{track_id}'
#     track_features = sp.audio_features(track_uri)

#     if track_features:
#         # Extract relevant features
#         features = track_features[0]

#         # Append the features to the DataFrame
#         feature_values = [features['acousticness'], features['danceability'], features['energy'],
#                           features['instrumentalness'], features['liveness'], features['speechiness'],
#                           features['tempo'], features['valence']]

#         df = df.append(pd.Series(feature_values, index=columns), ignore_index=True)

#         # Display the DataFrame if needed
#         print("DataFrame after adding track features:")
#         #print(df)
#     else:
#         print("Track features not available.")
# else:
#     print("Failed to extract track ID.")

# df.head()

# stressed_out_echonest_features = df
