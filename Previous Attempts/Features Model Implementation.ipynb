# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# !pip install librosa
# Out:
# Mounted at /content/drive
# ...

# %%
# Import libraries
import numpy as np
import pandas as pd
import librosa
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from joblib import load
import matplotlib.pyplot as plt
from google.colab import files

# %%
# Load the KMeans model
model_path = "/content/drive/Shareddrives/Machine Learning Group Project/features_kmeans_model.joblib"
kmeans = load(model_path)

# %%
# Function to extract features from an audio file using librosa
def extract_features(audio_path):
    y, sr = librosa.load(audio_path)
    # Add your feature extraction code here
    # For example, you can use the same features as in your original dataframe
    features = np.array([])  # Replace with your actual feature extraction code
    return features

# %%
# Extract features using librosa
features = extract_features("/content/drive/Shareddrives/Machine Learning Group Project/Songs for Testing/twenty one pilots - Stressed Out (Audio).mp3")

# %%
# Check if features are empty
if len(features) == 0:
    print("Error: No features extracted from the audio file.")
else:
    # Scale the features
    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features.reshape(1, -1))

    # Predict the cluster
    cluster = kmeans.predict(features_scaled)[0]
# Out:
# Error: No features extracted from the audio file.
