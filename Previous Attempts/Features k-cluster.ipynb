# %%
import numpy as np
import pandas as pd
import librosa
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from joblib import dump

# %%
# Load data
features = pd.read_csv("/content/drive/Shareddrives/Machine Learning Group Project/encoded_features.csv")

# %%
features.head()
# Out:
#    chroma_cens  chroma_cens.1  chroma_cens.2  chroma_cens.3  chroma_cens.4  \
# 0     7.180653       5.230309       0.249321       1.347620       1.482478
# 1     1.888963       0.760539       0.345297       2.295201       1.654031
# 2     0.527563      -0.077654      -0.279610       0.685883       1.937570
# 3     3.702245      -0.291193       2.196742      -0.234449       1.367364
# 4    -0.193837      -0.198527       0.201546       0.258556       0.775204
#
#    chroma_cens.5  chroma_cens.6  chroma_cens.7  chroma_cens.8  chroma_cens.9  \
# 0       0.531371       1.481593       2.691455       0.866868       1.341231
# 1       0.067592       1.366848       1.054094       0.108103       0.619185
# 2       0.880839      -0.923192      -0.927232       0.666617       1.038546
# 3       0.998411       1.770694       1.604566       0.521217       1.982386
# 4       0.084794      -0.289294      -0.816410       0.043851      -0.804761
#
# ...

# %%
# features = features.drop('cluster', axis=1)

# %%
X = features.values  # Assuming all columns are features

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
optimal_k = 100
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=100, random_state=42)

# %%
from sklearn.decomposition import PCA

# Apply PCA to reduce dimensionality to 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Add the cluster assignments to the reduced data
X_with_clusters = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
X_with_clusters['cluster'] = kmeans.labels_

# Visualize the clusters
plt.figure(figsize=(10, 6))
for cluster in range(optimal_k):
    cluster_points = X_with_clusters[X_with_clusters['cluster'] == cluster]
    plt.scatter(cluster_points['PC1'], cluster_points['PC2'], label=f'Cluster {cluster + 1}')

plt.title('KMeans Clustering Result (2D PCA)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.show()

# %%
model_path = "/content/drive/Shareddrives/Machine Learning Group Project/features_kmeans_model.joblib"
dump(kmeans, model_path)
# Out:
# ['/content/drive/Shareddrives/Machine Learning Group Project/features_kmeans_model.joblib']
